# %%
import os, shutil

# %%
INPUTFOLDER = '/home/haehn/Dropbox/RESEARCH/MITOCHONDRIA/haehnassignment1_align/haehnassignment1_data/'

# %%
OUTPUTFOLDER = '/home/haehn/Dropbox/RESEARCH/MITOCHONDRIA/xp1/'

# %%
# source images
files = os.listdir(INPUTFOLDER+'/Test_Images_Star')
for f in files:
    print(f)
    new_name = f.replace('.png', '_source.png')
    shutil.copyfile(INPUTFOLDER+'/Test_Images_Star/'+f, OUTPUTFOLDER+'/test/'+new_name)
# Out:
# 41.png
# 15.png
# 35.png
# 9.png
# 13.png
# 22.png
# 18.png
# 48.png
# 26.png
# 43.png
# 55.png
# 39.png
# 3.png
# 49.png
# 16.png
# 6.png
# 37.png
# 46.png
# 30.png
# 24.png
# 2.png
# 21.png
# 32.png
# 5.png
# 8.png
# 56.png
# 11.png
# 38.png
# 36.png
# 12.png
# 27.png
# 44.png
# 25.png
# 33.png
# 34.png
# 50.png
# 59.png
# 54.png
# 28.png
# 4.png
# 47.png
# 58.png
# 40.png
# 14.png
# 29.png
# 45.png
# 19.png
# 10.png
# 20.png
# 23.png
# 52.png
# 57.png
# 51.png
# 17.png
# 42.png
# 7.png
# 53.png
# 1.png
# 31.png
# 0.png

# %%
# target images
files = os.listdir(INPUTFOLDER+'/Test_Images')
for f in files:
    print(f)
    new_name = f.replace('.png', '_target.png')
    shutil.copyfile(INPUTFOLDER+'/Test_Images/'+f, OUTPUTFOLDER+'/test/'+new_name)
# Out:
# 41.png
# 15.png
# 35.png
# 9.png
# 13.png
# 22.png
# 18.png
# 48.png
# 26.png
# 43.png
# 55.png
# 39.png
# 3.png
# 49.png
# 16.png
# 6.png
# 37.png
# 46.png
# 30.png
# 24.png
# 2.png
# 21.png
# 32.png
# 5.png
# 8.png
# 56.png
# 11.png
# 38.png
# 36.png
# 12.png
# 27.png
# 44.png
# 25.png
# 33.png
# 34.png
# 50.png
# 59.png
# 54.png
# 28.png
# 4.png
# 47.png
# 58.png
# 40.png
# 14.png
# 29.png
# 45.png
# 19.png
# 10.png
# 20.png
# 23.png
# 52.png
# 57.png
# 51.png
# 17.png
# 42.png
# 7.png
# 53.png
# 1.png
# 31.png
# 0.png

# %%
# source masks
files = os.listdir(INPUTFOLDER+'/Test_Masks_Star')
for f in files:
    print(f)
    new_name = f.replace('.png', '_source_seg.png')
    shutil.copyfile(INPUTFOLDER+'/Test_Masks_Star/'+f, OUTPUTFOLDER+'/test/'+new_name)
# Out:
# 41.png
# 15.png
# 35.png
# 9.png
# 13.png
# 22.png
# 18.png
# 48.png
# 26.png
# 43.png
# 55.png
# 39.png
# 3.png
# 49.png
# 16.png
# 6.png
# 37.png
# 46.png
# 30.png
# 24.png
# 2.png
# 21.png
# 32.png
# 5.png
# 8.png
# 56.png
# 11.png
# 38.png
# 36.png
# 12.png
# 27.png
# 44.png
# 25.png
# 33.png
# 34.png
# 50.png
# 59.png
# 54.png
# 28.png
# 4.png
# 47.png
# 58.png
# 40.png
# 14.png
# 29.png
# 45.png
# 19.png
# 10.png
# 20.png
# 23.png
# 52.png
# 57.png
# 51.png
# 17.png
# 42.png
# 7.png
# 53.png
# 1.png
# 31.png
# 0.png

# %%
# target images
files = os.listdir(INPUTFOLDER+'/Test_Masks')
for f in files:
    print(f)
    new_name = f.replace('.png', '_target_seg.png')
    shutil.copyfile(INPUTFOLDER+'/Test_Masks/'+f, OUTPUTFOLDER+'/test/'+new_name)
# Out:
# 41.png
# 15.png
# 35.png
# 9.png
# 13.png
# 22.png
# 18.png
# 48.png
# 26.png
# 43.png
# 55.png
# 39.png
# 3.png
# 49.png
# 16.png
# 6.png
# 37.png
# 46.png
# 30.png
# 24.png
# 2.png
# 21.png
# 32.png
# 5.png
# 8.png
# 56.png
# 11.png
# 38.png
# 36.png
# 12.png
# 27.png
# 44.png
# 25.png
# 33.png
# 34.png
# 50.png
# 59.png
# 54.png
# 28.png
# 4.png
# 47.png
# 58.png
# 40.png
# 14.png
# 29.png
# 45.png
# 19.png
# 10.png
# 20.png
# 23.png
# 52.png
# 57.png
# 51.png
# 17.png
# 42.png
# 7.png
# 53.png
# 1.png
# 31.png
# 0.png
